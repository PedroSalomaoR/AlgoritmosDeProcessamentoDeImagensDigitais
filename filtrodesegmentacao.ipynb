# %% [markdown]
# <a href="https://colab.research.google.com/github/PedroSalomaoR/AlgoritmosDeProcessamentoDeImagensDigitais/blob/main/filtrodesegmentacao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import sys
import urllib.request

url = "https://raw.githubusercontent.com/YoniChechik/AI_is_Math/master/c_02a_basic_image_processing/grass.jpg"
urllib.request.urlretrieve(url, "grass.jpg")
# Out:
# ('grass.jpg', <http.client.HTTPMessage at 0x7dc2641bb410>)

# %%
figsize = (10, 10)

# %%
bgr_im = cv2.imread("grass.jpg")
rgb_im = cv2.cvtColor(bgr_im, cv2.COLOR_BGR2RGB)
plt.figure(figsize=figsize)
plt.imshow(rgb_im)
plt.title("Original")
#plt.axis("off")  opcional: remove os eixos
plt.show()

# %%
rgb_green = np.uint8([[[0, 255, 0]]])
hsv_green = cv2.cvtColor(rgb_green, cv2.COLOR_RGB2HSV)[0, 0, :]
print(hsv_green)
# Out:
# [ 60 255 255]

# %%
hsv_im = cv2.cvtColor(rgb_im, cv2.COLOR_RGB2HSV)

lower_th = hsv_green - np.array([70, 200, 200])
upper_th = hsv_green + np.array([30, 0, 0])

mask = cv2.inRange(hsv_im, lower_th, upper_th)
plt.figure(figsize=figsize)
plt.imshow(mask)
plt.title("Resultado")
plt.show()

# %%
rgb_res = cv2.bitwise_and(rgb_im, rgb_im, mask=mask)
plt.figure(figsize=figsize)
plt.imshow(rgb_res)
plt.title("Resultado")
plt.show()
